# %%
import numpy as np
from random import randint, choice
from create_cromosom import get_cromosoma

# %%
import get_hours 
import get_teachers
import get_courses_period
import get_professors_for_course
import get_groups
import get_max_hours

# %%
period_even = get_courses_period.get_courses_period(True)
period_odd = get_courses_period.get_courses_period(False)
professors_for_course = get_professors_for_course.get_professors_for_course()
hours = get_hours.hoursCoursesUDF()
teachers = get_teachers.get_teachers()
groups_even = get_groups.get_period(False)
groups_odd = get_groups.get_period(True)
teachers_max = get_max_hours.get_max_hours()

# %%
cromosome = get_cromosoma(True)
cromosome
# Out:
# [['TC1032',
#   1,
#   2,
#   1,
#   'Yerly Flores',
#   4,
#   {'Jueves': [12, 14], 'Martes': [13], 'Viernes': [12]}],
#  ['TC1031',
#   1,
#   3,
#   1,
#   'Roberto Leyva',
#   4,
#   {'Miercoles': [9], 'Jueves': [15], 'Lunes': [13, 14]}],
#  ['TC1028',
#   8,
#   1,
#   1,
#   'Pedro Hernandez',
#   4,
#   {'Jueves': [12, 13], 'Miercoles': [19], 'Viernes': [17]}],
#  ['TC1028',
#   6,
#   2,
#   1,
#   'Víctor Mañón',
#   4,
#   {'Jueves': [20], 'Martes': [16], 'Viernes': [9], 'Miercoles': [19]}],
#  ['TC2008B', 1, 3, 4, 'Ivan Olmos', 2, {'Martes': [17], 'Miercoles': [11]}],
#  ['TC1028',
#   4,
#   2,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Viernes': [13], 'Martes': [16], 'Miercoles': [20], 'Jueves': [15]}],
#  ['TC2038',
#   1,
#   3,
#   1,
#   'Mauricio Paletta',
#   4,
#   {'Miercoles': [9], 'Viernes': [8, 10, 15]}],
#  ['TI1015',
#   1,
#   3,
#   1,
#   'María Mirafuentes',
#   4,
#   {'Viernes': [7, 9], 'Martes': [16], 'Miercoles': [10]}],
#  ['TC2038',
#   1,
#   2,
#   1,
#   'José Aguilera',
#   4,
#   {'Martes': [18], 'Miercoles': [8, 17], 'Jueves': [17]}],
#  ['TI1015', 1, 3, 1, 'Roberto Leyva', 4, {'Viernes': [7, 11, 12, 14]}],
#  ['TI1015',
#   1,
#   3,
#   1,
#   'Roberto Vera',
#   4,
#   {'Jueves': [13], 'Viernes': [20], 'Martes': [15, 17]}],
#  ['TC1032',
#   1,
#   2,
#   1,
#   'Israel Tabarez',
#   4,
#   {'Jueves': [15], 'Lunes': [12], 'Viernes': [11], 'Martes': [20]}],
#  ['TC2008B', 1, 3, 3, 'Ivan Olmos', 2, {'Viernes': [9], 'Miercoles': [18]}],
#  ['TC1031',
#   1,
#   2,
#   1,
#   'Mauricio Paletta',
#   4,
#   {'Viernes': [8], 'Miercoles': [7], 'Jueves': [8, 14]}],
#  ['TC2038',
#   1,
#   3,
#   1,
#   'José Aguilera',
#   4,
#   {'Viernes': [10], 'Jueves': [8, 14, 20]}],
#  ['TC1032',
#   1,
#   2,
#   1,
#   'Jorge Rodríguez',
#   4,
#   {'Viernes': [8], 'Martes': [15], 'Miercoles': [9], 'Lunes': [19]}],
#  ['TC2038',
#   1,
#   1,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Lunes': [18], 'Martes': [15, 18], 'Miercoles': [20]}],
#  ['TC1033',
#   1,
#   3,
#   1,
#   'Víctor Mañón',
#   4,
#   {'Lunes': [10], 'Jueves': [16], 'Viernes': [12], 'Martes': [7]}],
#  ['TC1033',
#   1,
#   3,
#   1,
#   'Víctor Mañón',
#   4,
#   {'Lunes': [14, 15], 'Miercoles': [18], 'Jueves': [7]}],
#  ['TC2038',
#   1,
#   3,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Miercoles': [10, 13], 'Martes': [8], 'Lunes': [10]}],
#  ['TC1028',
#   4,
#   1,
#   1,
#   'Roberto Vera',
#   4,
#   {'Lunes': [7], 'Jueves': [16], 'Martes': [12, 17]}],
#  ['TC2038', 1, 1, 1, 'José Aguilera', 4, {'Jueves': [8, 10, 12, 13]}],
#  ['TI1015',
#   1,
#   3,
#   1,
#   'María Mirafuentes',
#   4,
#   {'Martes': [13], 'Viernes': [10], 'Lunes': [12], 'Miercoles': [19]}],
#  ['TC1032',
#   1,
#   2,
#   1,
#   'Jorge Rodríguez',
#   4,
#   {'Miercoles': [20], 'Martes': [16], 'Viernes': [19], 'Lunes': [18]}],
#  ['TC1033',
#   1,
#   3,
#   1,
#   'Víctor Mañón',
#   4,
#   {'Viernes': [14], 'Lunes': [9], 'Miercoles': [14], 'Martes': [8]}],
#  ['TC2007B', 1, 2, 2, 'Yerly Flores', 2, {'Lunes': [10], 'Martes': [18]}],
#  ['TC2007B',
#   1,
#   1,
#   4,
#   'Roberto Leyva',
#   5,
#   {'Jueves': [20], 'Miercoles': [12, 16], 'Martes': [9], 'Viernes': [10]}],
#  ['TC1031',
#   1,
#   1,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Viernes': [9, 16], 'Miercoles': [12, 18]}],
#  ['TI1015',
#   1,
#   3,
#   1,
#   'José Aguilera',
#   4,
#   {'Miercoles': [9, 16], 'Viernes': [9], 'Martes': [15]}],
#  ['TC1027',
#   1,
#   2,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Martes': [9, 17], 'Lunes': [8, 15]}],
#  ['TC2008B', 1, 3, 7, 'Israel Tabarez', 2, {'Jueves': [19], 'Lunes': [17]}],
#  ['TC1033',
#   1,
#   3,
#   1,
#   'Víctor Mañón',
#   4,
#   {'Martes': [12], 'Lunes': [16], 'Viernes': [12, 15]}],
#  ['TC2007B', 1, 2, 2, 'Yerly Flores', 2, {'Miercoles': [16], 'Martes': [8]}],
#  ['TC1001B', 1, 3, 6, 'Jorge Rodríguez', 1, {'Martes': [19]}],
#  ['TC1004B', 1, 3, 4, 'Jaime López', 0, {}],
#  ['TC1028',
#   7,
#   2,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Martes': [8, 14], 'Viernes': [17], 'Jueves': [20]}],
#  ['TC1028',
#   8,
#   1,
#   1,
#   'Pedro Hernandez',
#   4,
#   {'Miercoles': [10, 16], 'Martes': [10, 19]}],
#  ['TC2038',
#   1,
#   1,
#   1,
#   'José Aguilera',
#   4,
#   {'Martes': [18], 'Viernes': [13, 17], 'Miercoles': [12]}],
#  ['TC1033',
#   1,
#   3,
#   1,
#   'Víctor Mañón',
#   4,
#   {'Viernes': [14], 'Miercoles': [15], 'Martes': [11], 'Lunes': [19]}],
#  ['TC1001B', 1, 3, 6, 'Octavio Silva', 1, {'Viernes': [20]}],
#  ['TC1032',
#   1,
#   2,
#   1,
#   'Yerly Flores',
#   4,
#   {'Viernes': [16], 'Lunes': [10], 'Miercoles': [9], 'Jueves': [20]}],
#  ['TC1001B', 1, 3, 1, 'Jorge Rodríguez', 0, {}],
#  ['TC1001B', 1, 3, 7, 'Octavio Silva', 0, {}],
#  ['TC1033',
#   1,
#   3,
#   1,
#   'Víctor Mañón',
#   4,
#   {'Viernes': [15], 'Jueves': [17], 'Miercoles': [15], 'Martes': [16]}],
#  ['TC1028',
#   6,
#   1,
#   1,
#   'Roberto Vera',
#   4,
#   {'Lunes': [11], 'Miercoles': [12], 'Viernes': [7, 18]}],
#  ['TC1028',
#   6,
#   2,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Viernes': [7, 10], 'Jueves': [18], 'Martes': [16]}],
#  ['TC1001B', 1, 3, 6, 'Octavio Silva', 1, {'Martes': [16]}],
#  ['TC1004B', 1, 2, 5, 'Israel Tabarez', 0, {}],
#  ['TC2007B', 1, 1, 6, 'Juan Alvarado', 2, {'Martes': [15, 16]}],
#  ['TC2038',
#   1,
#   1,
#   1,
#   'Mauricio Paletta',
#   4,
#   {'Miercoles': [15], 'Jueves': [18], 'Viernes': [13], 'Martes': [18]}],
#  ['TC2007B', 1, 2, 2, 'Víctor Mañón', 2, {'Miercoles': [10], 'Jueves': [8]}],
#  ['TC2008B', 1, 3, 7, 'Israel Tabarez', 2, {'Martes': [10], 'Viernes': [8]}],
#  ['TC1032', 1, 2, 1, 'Yerly Flores', 4, {'Martes': [9, 14], 'Lunes': [7, 14]}],
#  ['TC2038',
#   1,
#   3,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Miercoles': [12], 'Viernes': [11, 12], 'Lunes': [10]}],
#  ['TC1032',
#   1,
#   2,
#   1,
#   'Yerly Flores',
#   4,
#   {'Lunes': [17, 18], 'Jueves': [12, 18]}],
#  ['TC1027',
#   2,
#   2,
#   1,
#   'Roberto Leyva',
#   4,
#   {'Martes': [10, 20], 'Viernes': [16], 'Lunes': [15]}],
#  ['TC1031',
#   1,
#   2,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Viernes': [7], 'Miercoles': [18], 'Jueves': [18, 20]}],
#  ['TC1027',
#   2,
#   2,
#   1,
#   'Pedro Hernandez',
#   4,
#   {'Martes': [15, 17, 18], 'Lunes': [10]}],
#  ['TC2008B', 1, 3, 3, 'Pedro Hernandez', 2, {'Lunes': [7], 'Jueves': [13]}],
#  ['TC1033',
#   1,
#   3,
#   1,
#   'Víctor Mañón',
#   4,
#   {'Martes': [14], 'Miercoles': [11], 'Lunes': [13], 'Jueves': [15]}],
#  ['TC1028',
#   5,
#   1,
#   1,
#   'Pedro Hernandez',
#   4,
#   {'Lunes': [14, 20], 'Jueves': [10, 17]}],
#  ['TC1027',
#   2,
#   2,
#   1,
#   'Pedro Hernandez',
#   4,
#   {'Martes': [9], 'Jueves': [18], 'Miercoles': [7, 11]}],
#  ['TC2008B', 1, 3, 1, 'Mauricio Paletta', 1, {'Jueves': [12]}],
#  ['TC2038',
#   1,
#   1,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Martes': [7, 20], 'Viernes': [18], 'Lunes': [11]}],
#  ['TC2008B', 1, 3, 6, 'Pedro Hernandez', 2, {'Lunes': [16], 'Jueves': [18]}],
#  ['TC1004B',
#   1,
#   3,
#   6,
#   'Pedro Hernandez',
#   2,
#   {'Miercoles': [8], 'Viernes': [9]}],
#  ['TC1033',
#   1,
#   3,
#   1,
#   'Víctor Mañón',
#   4,
#   {'Jueves': [8, 19], 'Viernes': [19], 'Miercoles': [10]}],
#  ['TI1015',
#   1,
#   3,
#   1,
#   'Pedro Hernandez',
#   4,
#   {'Viernes': [11, 15], 'Jueves': [20], 'Miercoles': [16]}],
#  ['TI1015',
#   1,
#   3,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Martes': [8], 'Lunes': [13], 'Viernes': [11], 'Jueves': [15]}],
#  ['TC2008B', 1, 3, 5, 'Ivan Olmos', 2, {'Jueves': [7, 9]}],
#  ['TC2008B', 1, 3, 2, 'Roberto Leyva', 2, {'Jueves': [18], 'Martes': [16]}],
#  ['TC1028',
#   4,
#   2,
#   1,
#   'Víctor Mañón',
#   4,
#   {'Martes': [12, 15, 19], 'Lunes': [17]}],
#  ['TC1027',
#   2,
#   2,
#   1,
#   'Roberto Vera',
#   4,
#   {'Miercoles': [16], 'Viernes': [9, 10], 'Martes': [7]}]]

# %%
#['TC3008', 'G1', 'P2', 'M1', 'Victor Manon', '#Horas a la semana', 'Horario']

# %%
print(cromosome[0])
print(cromosome[1])
print(cromosome[2])
# Out:
# ['TC1032', 1, 2, 1, 'Yerly Flores', 4, {'Jueves': [12, 14], 'Martes': [13], 'Viernes': [12]}]
# ['TC1031', 1, 3, 1, 'Roberto Leyva', 4, {'Miercoles': [9], 'Jueves': [15], 'Lunes': [13, 14]}]
# ['TC1028', 8, 1, 1, 'Pedro Hernandez', 4, {'Jueves': [12, 13], 'Miercoles': [19], 'Viernes': [17]}]

# %%
gen_element = randint(1,len(cromosome[0]))
print(cromosome[0][gen_element])
# Out:
# Yerly Flores

# %%
#['TC3008', 'G1', 'P2', 'M1', 'Victor Manon', '#Horas a la semana', 'Horario']

# %%
print(professors_for_course['TC3002B'])
print(list(professors_for_course['TC3002B'].keys()))
print(list(professors_for_course['TC3002B']['1']))
# Out:
# {'1': ['Juan Alvarado', 'Roberto Leyva', 'Mauricio Paletta'], '2': ['Roberto Leyva', 'Mauricio Paletta'], '3': ['Mauricio Paletta', 'José Aguilera'], '4': ['Pedro Hernandez']}
# ['1', '2', '3', '4']
# ['Juan Alvarado', 'Roberto Leyva', 'Mauricio Paletta']

# %%
def mutation_operator(cromesome, semester):

    groups = groups_even
    if semester: groups = groups_odd
    periods = period_even
    if semester: periods = period_odd

    
    gen_i = randint(0,len(cromosome)-1)
    pick_gen_element = choice([1,2])
    gen = cromosome[gen_i]
    print(gen)
    if pick_gen_element == 1:#Profesor de modulo
        options = list(professors_for_course[gen[0]][str(gen[3])])
        #options = list(professors_for_course['TC1001B'][str(gen[3])])
        #print(options)
        #print(gen)
        #m = randint(0,len(options)-1)
        m = choice(options)
        #print('m',m)
        gen[4] = m
        #print(gen)
        return gen
    
    elif pick_gen_element == 2: #Horario
        days = ['Lunes', 'Martes', 'Miercoles', 'Jueves', 'Viernes']

        hour = gen[5]
        #print(hour)
        horario = {}
        while hour != 0:
            day = choice(days)
            new_hour = randint(7,20)
            if day in horario:
                if new_hour not in horario[day]:
                    horario[day].append(new_hour)
                    hour -= 1
            else:
                horario[day] = [new_hour]
                hour -= 1
        
        for day in horario.keys():
            horario[day].sort()

        gen[6] = horario
        #print(gen)
        return gen

# %%
mutation_operator(cromosome, True)
# Out:
# ['TC1033', 1, 3, 1, 'Víctor Mañón', 4, {'Viernes': [14], 'Lunes': [9], 'Miercoles': [14], 'Martes': [8]}]
# ['TC1033',
#  1,
#  3,
#  1,
#  'Víctor Mañón',
#  4,
#  {'Martes': [7], 'Lunes': [14], 'Jueves': [14], 'Miercoles': [19]}]

# %%
#['TC3008', 'G1', 'P2', 'M1', 'Victor Manon', '#Horas a la semana', 'Horario']
