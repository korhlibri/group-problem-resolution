# %%
import numpy as np
from random import randint, choice
from create_cromosom import get_cromosoma

# %%
import get_hours 
import get_teachers
import get_courses_period
import get_professors_for_course
import get_groups
import get_max_hours

# %%
period_even = get_courses_period.get_courses_period(True)
period_odd = get_courses_period.get_courses_period(False)
professors_for_course = get_professors_for_course.get_professors_for_course()
hours = get_hours.hoursCoursesUDF()
teachers = get_teachers.get_teachers()
groups_even = get_groups.get_period(False)
groups_odd = get_groups.get_period(True)
teachers_max = get_max_hours.get_max_hours()

# %%
cromosome = get_cromosoma(True)
cromosome
# Out:
# [['TC1028',
#   1,
#   1,
#   1,
#   'José Aguilera',
#   4,
#   {'Miercoles': [14, 18, 20], 'Jueves': [12]}],
#  ['TC2008B', 1, 3, 2, 'Roberto Leyva', 2, {'Viernes': [18], 'Jueves': [7]}],
#  ['TC2038',
#   1,
#   2,
#   1,
#   'José Aguilera',
#   4,
#   {'Miercoles': [13], 'Viernes': [7, 8], 'Jueves': [15]}],
#  ['TC1001B', 1, 3, 6, 'Octavio Silva', 1, {'Lunes': [9]}],
#  ['TC1027',
#   3,
#   2,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Lunes': [8], 'Jueves': [11], 'Martes': [12], 'Viernes': [14]}],
#  ['TC1001B', 1, 3, 3, 'Juan Alvarado', 1, {'Martes': [13]}],
#  ['TC1031',
#   1,
#   2,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Viernes': [18], 'Martes': [13, 17], 'Lunes': [16]}],
#  ['TC1001B', 1, 3, 1, 'Jorge Rodríguez', 0, {}],
#  ['TC2038',
#   1,
#   1,
#   1,
#   'Mauricio Paletta',
#   4,
#   {'Lunes': [16], 'Miercoles': [13], 'Viernes': [16], 'Jueves': [8]}],
#  ['TC1004B', 1, 2, 1, 'Jaime López', 1, {'Viernes': [14]}],
#  ['TC2038',
#   1,
#   1,
#   1,
#   'Mauricio Paletta',
#   4,
#   {'Jueves': [8], 'Lunes': [19], 'Miercoles': [19], 'Viernes': [10]}],
#  ['TC1027',
#   3,
#   2,
#   1,
#   'Roberto Leyva',
#   4,
#   {'Jueves': [10], 'Miercoles': [7, 14], 'Viernes': [9]}],
#  ['TC1033',
#   1,
#   3,
#   1,
#   'Víctor Mañón',
#   4,
#   {'Viernes': [12], 'Miercoles': [11, 18], 'Jueves': [18]}],
#  ['TC1001B', 1, 3, 6, 'Jorge Rodríguez', 1, {'Miercoles': [20]}],
#  ['TC1001B',
#   1,
#   3,
#   5,
#   'Mauricio Paletta',
#   4,
#   {'Jueves': [19], 'Lunes': [14, 19], 'Viernes': [11]}],
#  ['TC2007B', 1, 1, 1, 'Yerly Flores', 1, {'Viernes': [20]}],
#  ['TC1032',
#   1,
#   2,
#   1,
#   'Jorge Rodríguez',
#   4,
#   {'Jueves': [18, 19], 'Lunes': [7], 'Martes': [18]}],
#  ['TI1015',
#   1,
#   3,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Viernes': [16, 19], 'Miercoles': [10, 13]}],
#  ['TC1027',
#   4,
#   2,
#   1,
#   'Roberto Leyva',
#   4,
#   {'Martes': [8, 14], 'Lunes': [7, 19]}],
#  ['TC2007B', 1, 1, 6, 'Juan Alvarado', 2, {'Jueves': [8], 'Martes': [13]}],
#  ['TC2038',
#   1,
#   1,
#   1,
#   'José Aguilera',
#   4,
#   {'Miercoles': [12], 'Viernes': [7], 'Lunes': [17], 'Jueves': [10]}],
#  ['TC1001B', 1, 3, 4, 'Jorge Rodríguez', 1, {'Jueves': [20]}],
#  ['TC1028',
#   7,
#   1,
#   1,
#   'Pedro Hernandez',
#   4,
#   {'Martes': [11, 19], 'Lunes': [7], 'Jueves': [16]}],
#  ['TC1028',
#   7,
#   2,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Miercoles': [8, 15], 'Lunes': [14], 'Jueves': [18]}],
#  ['TC1033',
#   1,
#   3,
#   1,
#   'Víctor Mañón',
#   4,
#   {'Jueves': [14, 17], 'Viernes': [9], 'Miercoles': [12]}],
#  ['TI1015',
#   1,
#   3,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Viernes': [16], 'Miercoles': [7, 14], 'Martes': [16]}],
#  ['TC1031',
#   1,
#   1,
#   1,
#   'José Aguilera',
#   4,
#   {'Miercoles': [14, 16], 'Lunes': [19], 'Viernes': [18]}],
#  ['TC1004B', 1, 3, 3, 'Jaime López', 0, {}],
#  ['TC1033',
#   1,
#   3,
#   1,
#   'Víctor Mañón',
#   4,
#   {'Viernes': [13], 'Lunes': [14, 15], 'Martes': [11]}],
#  ['TC1001B', 1, 3, 1, 'Jorge Rodríguez', 0, {}],
#  ['TC1027',
#   4,
#   2,
#   1,
#   'Roberto Vera',
#   4,
#   {'Lunes': [15], 'Jueves': [15], 'Viernes': [10], 'Martes': [12]}],
#  ['TC2038',
#   1,
#   1,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Viernes': [15], 'Lunes': [20], 'Martes': [13], 'Miercoles': [15]}],
#  ['TC2008B', 1, 3, 7, 'Israel Tabarez', 2, {'Martes': [17], 'Viernes': [15]}],
#  ['TC1031',
#   1,
#   2,
#   1,
#   'José Aguilera',
#   4,
#   {'Jueves': [7, 9, 12], 'Viernes': [10]}],
#  ['TC2038',
#   1,
#   3,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Miercoles': [16], 'Viernes': [12, 15], 'Lunes': [13]}],
#  ['TI1015',
#   1,
#   3,
#   1,
#   'María Mirafuentes',
#   4,
#   {'Viernes': [14], 'Miercoles': [11, 15], 'Lunes': [19]}],
#  ['TC1027',
#   3,
#   2,
#   1,
#   'Pedro Hernandez',
#   4,
#   {'Miercoles': [10, 18, 19], 'Viernes': [19]}],
#  ['TC1001B', 1, 3, 2, 'Mauricio Paletta', 1, {'Jueves': [18]}],
#  ['TC1028',
#   6,
#   2,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Miercoles': [9, 13], 'Viernes': [11, 19]}],
#  ['TC1027',
#   2,
#   2,
#   1,
#   'Mauricio Paletta',
#   4,
#   {'Miercoles': [17], 'Lunes': [16, 20], 'Martes': [11]}],
#  ['TC2008B', 1, 3, 2, 'Roberto Leyva', 2, {'Viernes': [9, 14]}],
#  ['TC1033',
#   1,
#   3,
#   1,
#   'Víctor Mañón',
#   4,
#   {'Jueves': [10, 11], 'Martes': [9], 'Miercoles': [7]}],
#  ['TC2038',
#   1,
#   2,
#   1,
#   'Mauricio Paletta',
#   4,
#   {'Viernes': [14, 18], 'Lunes': [10], 'Miercoles': [18]}],
#  ['TC1031',
#   1,
#   2,
#   1,
#   'Mauricio Paletta',
#   4,
#   {'Lunes': [19], 'Jueves': [8, 11], 'Martes': [8]}],
#  ['TC1033',
#   1,
#   3,
#   1,
#   'Mauricio Paletta',
#   4,
#   {'Viernes': [14], 'Jueves': [9, 15], 'Lunes': [15]}],
#  ['TC1031',
#   1,
#   3,
#   1,
#   'Roberto Leyva',
#   4,
#   {'Viernes': [8, 13], 'Jueves': [9, 11]}],
#  ['TC1027',
#   1,
#   2,
#   1,
#   'José Aguilera',
#   4,
#   {'Miercoles': [19], 'Martes': [19], 'Viernes': [15], 'Jueves': [14]}],
#  ['TC1028',
#   8,
#   1,
#   1,
#   'Pedro Hernandez',
#   4,
#   {'Lunes': [7, 14], 'Miercoles': [7, 11]}],
#  ['TI1015',
#   1,
#   3,
#   1,
#   'Pedro Hernandez',
#   4,
#   {'Lunes': [9, 11], 'Miercoles': [7], 'Martes': [10]}],
#  ['TC1004B',
#   1,
#   2,
#   9,
#   'Fernando Ruiz',
#   3,
#   {'Lunes': [18], 'Martes': [16], 'Viernes': [20]}],
#  ['TC2007B', 1, 2, 3, 'Víctor Mañón', 2, {'Viernes': [7], 'Jueves': [8]}],
#  ['TC1001B', 1, 3, 2, 'Mauricio Paletta', 1, {'Miercoles': [18]}],
#  ['TC1031',
#   1,
#   3,
#   1,
#   'Víctor Mañón',
#   4,
#   {'Lunes': [12, 17], 'Jueves': [14, 18]}],
#  ['TC1033',
#   1,
#   3,
#   1,
#   'Mauricio Paletta',
#   4,
#   {'Jueves': [11, 14, 18], 'Martes': [16]}],
#  ['TC2008B',
#   1,
#   3,
#   7,
#   'Israel Tabarez',
#   2,
#   {'Miercoles': [7], 'Viernes': [14]}],
#  ['TC2008B', 1, 3, 3, 'Pedro Hernandez', 2, {'Viernes': [14], 'Martes': [10]}],
#  ['TC1004B', 1, 3, 5, 'Israel Tabarez', 0, {}],
#  ['TC1033',
#   1,
#   3,
#   1,
#   'Víctor Mañón',
#   4,
#   {'Jueves': [17], 'Viernes': [17], 'Martes': [13], 'Miercoles': [7]}],
#  ['TC2008B', 1, 3, 1, 'Roberto Leyva', 1, {'Martes': [15]}],
#  ['TC1031',
#   1,
#   3,
#   1,
#   'Víctor Mañón',
#   4,
#   {'Viernes': [12], 'Jueves': [13], 'Lunes': [7], 'Miercoles': [19]}],
#  ['TC1027',
#   1,
#   2,
#   1,
#   'Roberto Leyva',
#   4,
#   {'Lunes': [12, 16], 'Jueves': [13, 16]}],
#  ['TC1001B', 1, 3, 3, 'Víctor Mañón', 1, {'Miercoles': [17]}],
#  ['TC1001B', 1, 3, 2, 'Mauricio Paletta', 1, {'Miercoles': [17]}],
#  ['TC2008B', 1, 3, 5, 'Ivan Olmos', 2, {'Lunes': [11], 'Miercoles': [11]}],
#  ['TC1027',
#   4,
#   2,
#   1,
#   'Pedro Hernandez',
#   4,
#   {'Viernes': [8, 14], 'Jueves': [20], 'Martes': [20]}],
#  ['TC1031',
#   1,
#   1,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Viernes': [13, 14], 'Jueves': [18], 'Lunes': [12]}],
#  ['TC1031',
#   1,
#   1,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Jueves': [19], 'Viernes': [11, 16, 17]}],
#  ['TI1015',
#   1,
#   3,
#   1,
#   'José Aguilera',
#   4,
#   {'Miercoles': [13], 'Jueves': [10, 15], 'Martes': [8]}],
#  ['TC1001B', 1, 3, 7, 'Octavio Silva', 0, {}],
#  ['TC2007B',
#   1,
#   1,
#   5,
#   'Juan Alvarado',
#   3,
#   {'Jueves': [19], 'Martes': [9], 'Lunes': [9]}],
#  ['TC1027',
#   3,
#   2,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Lunes': [11, 12], 'Miercoles': [7], 'Viernes': [7]}],
#  ['TC1031',
#   1,
#   1,
#   1,
#   'Mauricio Paletta',
#   4,
#   {'Martes': [15, 20], 'Lunes': [9, 20]}],
#  ['TC1027',
#   1,
#   2,
#   1,
#   'Roberto Leyva',
#   4,
#   {'Lunes': [12, 13], 'Viernes': [16, 18]}]]

# %%
#['TC3008', 'G1', 'P2', 'M1', 'Victor Manon', '#Horas a la semana', 'Horario']

# %%
print(cromosome[0])
print(cromosome[1])
print(cromosome[2])
# Out:
# ['TC1028', 1, 1, 1, 'José Aguilera', 4, {'Miercoles': [14, 18, 20], 'Jueves': [12]}]
# ['TC2008B', 1, 3, 2, 'Roberto Leyva', 2, {'Viernes': [18], 'Jueves': [7]}]
# ['TC2038', 1, 2, 1, 'José Aguilera', 4, {'Miercoles': [13], 'Viernes': [7, 8], 'Jueves': [15]}]

# %%
gen_element = randint(1,len(cromosome[0]))
print(cromosome[0][gen_element])
# Out:
# {'Miercoles': [14, 18, 20], 'Jueves': [12]}

# %%
#['TC3008', 'G1', 'P2', 'M1', 'Victor Manon', '#Horas a la semana', 'Horario']

# %%
print(professors_for_course['TC3002B'])
print(list(professors_for_course['TC3002B'].keys()))
print(list(professors_for_course['TC3002B']['1']))
# Out:
# {'1': ['Juan Alvarado', 'Roberto Leyva', 'Mauricio Paletta'], '2': ['Roberto Leyva', 'Mauricio Paletta'], '3': ['Mauricio Paletta', 'José Aguilera'], '4': ['Pedro Hernandez']}
# ['1', '2', '3', '4']
# ['Juan Alvarado', 'Roberto Leyva', 'Mauricio Paletta']

# %%
def mutation_operator(cromesome, semester):

    groups = groups_even
    if semester: groups = groups_odd
    periods = period_even
    if semester: periods = period_odd

    
    gen_i = randint(0,len(cromosome)-1)
    pick_gen_element = choice([1,2])
    gen = cromosome[gen_i]
    print(gen)
    if pick_gen_element == 1:#Profesor de modulo
        #options = list(professors_for_course[gen[0]][str(gen[3])])
        options = list(professors_for_course['TC1001B'][str(gen[3])])
        #print(options)
        #print(gen)
        #m = randint(0,len(options)-1)
        m = choice(options)
        #print('m',m)
        gen[4] = m
        #print(gen)
        return gen
    
    elif pick_gen_element == 2: #Horario
        days = ['Lunes', 'Martes', 'Miercoles', 'Jueves', 'Viernes']

        hour = gen[5]
        #print(hour)
        horario = {}
        while hour != 0:
            day = choice(days)
            new_hour = randint(7,20)
            if day in horario:
                if new_hour not in horario[day]:
                    horario[day].append(new_hour)
                    hour -= 1
            else:
                horario[day] = [new_hour]
                hour -= 1
        
        for day in horario.keys():
            horario[day].sort()

        gen[6] = horario
        #print(gen)
        return gen

# %%
mutation_operator(cromosome, True)
# Out:
# ['TC1004B', 1, 2, 1, 'Jorge Rodríguez', 1, {'Viernes': [11]}]
# ['TC1004B', 1, 2, 1, 'Jorge Rodríguez', 1, {'Viernes': [11]}]

# %%
#['TC3008', 'G1', 'P2', 'M1', 'Victor Manon', '#Horas a la semana', 'Horario']
