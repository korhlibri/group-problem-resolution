# %%
import numpy as np
from random import randint, choice
from create_cromosom import get_cromosoma

# %%
import get_hours 
import get_teachers
import get_courses_period
import get_professors_for_course
import get_groups
import get_max_hours

# %%
period_even = get_courses_period.get_courses_period(True)
period_odd = get_courses_period.get_courses_period(False)
professors_for_course = get_professors_for_course.get_professors_for_course()
hours = get_hours.hoursCoursesUDF()
teachers = get_teachers.get_teachers()
groups_even = get_groups.get_period(False)
groups_odd = get_groups.get_period(True)
teachers_max = get_max_hours.get_max_hours()

# %%
cromosome = get_cromosoma(True)
cromosome
# Out:
# [['TC1001B', 1, 3, 6, 'Jorge Rodríguez', 1, {'Jueves': [18]}],
#  ['TC1033',
#   1,
#   3,
#   1,
#   'Mauricio Paletta',
#   4,
#   {'Lunes': [18], 'Viernes': [13, 15], 'Miercoles': [11]}],
#  ['TI1015',
#   1,
#   3,
#   1,
#   'Roberto Leyva',
#   4,
#   {'Viernes': [7], 'Lunes': [9], 'Martes': [12, 17]}],
#  ['TC2038',
#   1,
#   3,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Viernes': [12, 19], 'Martes': [16], 'Lunes': [7]}],
#  ['TC2038',
#   1,
#   1,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Viernes': [10], 'Jueves': [10], 'Lunes': [11, 12]}],
#  ['TC1031',
#   1,
#   1,
#   1,
#   'Roberto Leyva',
#   4,
#   {'Jueves': [7, 13], 'Miercoles': [11], 'Viernes': [8]}],
#  ['TC1033',
#   1,
#   3,
#   1,
#   'Mauricio Paletta',
#   4,
#   {'Viernes': [11, 20], 'Lunes': [7, 20]}],
#  ['TC2008B', 1, 3, 1, 'Roberto Leyva', 1, {'Lunes': [8]}],
#  ['TC1004B', 1, 3, 1, 'Israel Tabarez', 1, {'Martes': [10]}],
#  ['TC1032',
#   1,
#   2,
#   1,
#   'Yerly Flores',
#   4,
#   {'Lunes': [8, 10], 'Jueves': [13], 'Miercoles': [15]}],
#  ['TC1004B',
#   1,
#   2,
#   9,
#   'Israel Tabarez',
#   3,
#   {'Miercoles': [15, 20], 'Lunes': [16]}],
#  ['TC1028',
#   2,
#   1,
#   1,
#   'José Aguilera',
#   4,
#   {'Lunes': [8], 'Jueves': [11, 12], 'Viernes': [17]}],
#  ['TC1027',
#   4,
#   2,
#   1,
#   'Mauricio Paletta',
#   4,
#   {'Viernes': [9], 'Jueves': [10], 'Martes': [7], 'Miercoles': [18]}],
#  ['TC1027',
#   1,
#   2,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Viernes': [7, 8], 'Miercoles': [15], 'Lunes': [11]}],
#  ['TC1028',
#   8,
#   1,
#   1,
#   'Pedro Hernandez',
#   4,
#   {'Lunes': [17], 'Jueves': [17, 18], 'Martes': [12]}],
#  ['TC1004B', 1, 3, 2, 'Israel Tabarez', 1, {'Viernes': [8]}],
#  ['TC1033',
#   1,
#   3,
#   1,
#   'Víctor Mañón',
#   4,
#   {'Viernes': [19, 20], 'Miercoles': [9], 'Lunes': [8]}],
#  ['TC1027',
#   3,
#   2,
#   1,
#   'José Aguilera',
#   4,
#   {'Miercoles': [7, 12], 'Lunes': [7], 'Viernes': [18]}],
#  ['TC2008B', 1, 3, 2, 'Roberto Leyva', 2, {'Lunes': [19], 'Viernes': [7]}],
#  ['TC1004B', 1, 2, 2, 'Jaime López', 1, {'Viernes': [14]}],
#  ['TC1028',
#   5,
#   1,
#   1,
#   'Víctor Mañón',
#   4,
#   {'Martes': [20], 'Jueves': [14, 17], 'Lunes': [8]}],
#  ['TC1028',
#   3,
#   2,
#   1,
#   'Víctor Mañón',
#   4,
#   {'Miercoles': [10, 11], 'Viernes': [8], 'Lunes': [16]}],
#  ['TC2038',
#   1,
#   1,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Viernes': [18], 'Miercoles': [10, 17], 'Jueves': [12]}],
#  ['TC1001B', 1, 3, 1, 'Jorge Rodríguez', 0, {}],
#  ['TC1032',
#   1,
#   2,
#   1,
#   'Jorge Rodríguez',
#   4,
#   {'Jueves': [11], 'Viernes': [11, 15], 'Lunes': [19]}],
#  ['TC1031',
#   1,
#   2,
#   1,
#   'Mauricio Paletta',
#   4,
#   {'Viernes': [14], 'Martes': [13], 'Jueves': [10, 18]}],
#  ['TC2008B', 1, 3, 5, 'Pedro Hernandez', 2, {'Jueves': [9], 'Miercoles': [8]}],
#  ['TC1031',
#   1,
#   1,
#   1,
#   'Roberto Leyva',
#   4,
#   {'Jueves': [9, 17], 'Lunes': [9], 'Miercoles': [10]}],
#  ['TC1031',
#   1,
#   2,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Viernes': [11], 'Martes': [8], 'Lunes': [9, 15]}],
#  ['TI1015',
#   1,
#   3,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Miercoles': [10, 17, 20], 'Jueves': [11]}],
#  ['TC1001B', 1, 3, 2, 'Mauricio Paletta', 1, {'Lunes': [13]}],
#  ['TC1004B', 1, 2, 8, 'José Aguilera', 1, {'Martes': [14]}],
#  ['TC2007B', 1, 1, 2, 'Yerly Flores', 2, {'Lunes': [7], 'Viernes': [16]}],
#  ['TC2038',
#   1,
#   2,
#   1,
#   'José Aguilera',
#   4,
#   {'Martes': [13], 'Jueves': [10, 13], 'Miercoles': [18]}],
#  ['TC1033',
#   1,
#   3,
#   1,
#   'Mauricio Paletta',
#   4,
#   {'Jueves': [10], 'Martes': [13], 'Miercoles': [20], 'Viernes': [10]}],
#  ['TC2038',
#   1,
#   2,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Viernes': [16], 'Jueves': [16], 'Miercoles': [9, 15]}],
#  ['TC2008B', 1, 3, 3, 'Ivan Olmos', 2, {'Viernes': [14], 'Jueves': [9]}],
#  ['TC1031',
#   1,
#   2,
#   1,
#   'Mauricio Paletta',
#   4,
#   {'Martes': [15], 'Viernes': [7, 12], 'Lunes': [17]}],
#  ['TC1031',
#   1,
#   2,
#   1,
#   'José Aguilera',
#   4,
#   {'Lunes': [17], 'Jueves': [11], 'Martes': [16], 'Viernes': [20]}],
#  ['TI1015',
#   1,
#   3,
#   1,
#   'María Mirafuentes',
#   4,
#   {'Martes': [14, 19, 20], 'Lunes': [12]}],
#  ['TC2008B', 1, 3, 1, 'Mauricio Paletta', 1, {'Martes': [11]}],
#  ['TC1032',
#   1,
#   2,
#   1,
#   'Yerly Flores',
#   4,
#   {'Jueves': [7, 16], 'Martes': [9], 'Viernes': [19]}],
#  ['TC1004B', 1, 3, 3, 'Yerly Flores', 0, {}],
#  ['TC1028',
#   5,
#   2,
#   1,
#   'Víctor Mañón',
#   4,
#   {'Miercoles': [8], 'Martes': [8], 'Lunes': [18], 'Jueves': [17]}],
#  ['TC2008B',
#   1,
#   3,
#   2,
#   'Mauricio Paletta',
#   2,
#   {'Miercoles': [10], 'Jueves': [16]}],
#  ['TC1031',
#   1,
#   2,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Viernes': [18], 'Lunes': [13], 'Martes': [17], 'Jueves': [18]}],
#  ['TC2008B', 1, 3, 1, 'Mauricio Paletta', 1, {'Viernes': [20]}],
#  ['TC1032',
#   1,
#   2,
#   1,
#   'Yerly Flores',
#   4,
#   {'Jueves': [12, 14], 'Martes': [10], 'Miercoles': [11]}],
#  ['TC1031',
#   1,
#   3,
#   1,
#   'Mauricio Paletta',
#   4,
#   {'Viernes': [7, 14], 'Jueves': [18], 'Miercoles': [17]}],
#  ['TC1001B',
#   1,
#   3,
#   5,
#   'Mauricio Paletta',
#   4,
#   {'Martes': [7], 'Miercoles': [10, 11, 15]}],
#  ['TC1028',
#   1,
#   2,
#   1,
#   'José Aguilera',
#   4,
#   {'Martes': [10, 11], 'Lunes': [10], 'Viernes': [12]}],
#  ['TI1015',
#   1,
#   3,
#   1,
#   'María Mirafuentes',
#   4,
#   {'Jueves': [11, 12], 'Lunes': [16], 'Martes': [9]}],
#  ['TC2008B', 1, 3, 4, 'Ivan Olmos', 2, {'Martes': [11, 13]}],
#  ['TC1032',
#   1,
#   2,
#   1,
#   'Yerly Flores',
#   4,
#   {'Martes': [13], 'Jueves': [16], 'Lunes': [11, 20]}],
#  ['TC2008B', 1, 3, 4, 'Pedro Hernandez', 2, {'Miercoles': [10, 14]}],
#  ['TC1027',
#   1,
#   2,
#   1,
#   'Mauricio Paletta',
#   4,
#   {'Miercoles': [19], 'Viernes': [8, 13], 'Lunes': [9]}],
#  ['TC1004B', 1, 3, 5, 'Jaime López', 0, {}],
#  ['TC2038',
#   1,
#   1,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Jueves': [11, 12], 'Viernes': [10, 13]}],
#  ['TC1001B', 1, 3, 4, 'Jorge Rodríguez', 1, {'Lunes': [11]}],
#  ['TC1032',
#   1,
#   2,
#   1,
#   'Fernando Ruiz',
#   4,
#   {'Miercoles': [18], 'Lunes': [15], 'Martes': [18], 'Viernes': [9]}],
#  ['TC1027',
#   1,
#   2,
#   1,
#   'Pedro Hernandez',
#   4,
#   {'Martes': [15], 'Lunes': [9], 'Jueves': [19], 'Miercoles': [14]}],
#  ['TC2038',
#   1,
#   1,
#   1,
#   'Mauricio Paletta',
#   4,
#   {'Lunes': [11, 16], 'Martes': [18], 'Miercoles': [14]}],
#  ['TC1028',
#   5,
#   1,
#   1,
#   'Roberto Leyva',
#   4,
#   {'Lunes': [14], 'Viernes': [11], 'Miercoles': [13, 16]}],
#  ['TC1033',
#   1,
#   3,
#   1,
#   'Mauricio Paletta',
#   4,
#   {'Lunes': [7, 8], 'Martes': [7, 20]}],
#  ['TC1032',
#   1,
#   2,
#   1,
#   'Israel Tabarez',
#   4,
#   {'Lunes': [19], 'Jueves': [9, 18], 'Viernes': [7]}],
#  ['TC1028',
#   2,
#   2,
#   1,
#   'Roberto Vera',
#   4,
#   {'Lunes': [7, 19], 'Martes': [17], 'Viernes': [15]}],
#  ['TC2008B', 1, 3, 7, 'Israel Tabarez', 2, {'Lunes': [16], 'Jueves': [9]}],
#  ['TC1028',
#   3,
#   2,
#   1,
#   'José Aguilera',
#   4,
#   {'Miercoles': [11], 'Jueves': [13], 'Viernes': [17], 'Lunes': [17]}],
#  ['TC1031',
#   1,
#   2,
#   1,
#   'Juan Alvarado',
#   4,
#   {'Martes': [8], 'Viernes': [20], 'Lunes': [13], 'Jueves': [11]}],
#  ['TC2007B', 1, 2, 3, 'Víctor Mañón', 2, {'Viernes': [10], 'Lunes': [7]}],
#  ['TC1001B',
#   1,
#   3,
#   5,
#   'Roberto Leyva',
#   4,
#   {'Viernes': [8, 11], 'Miercoles': [12], 'Martes': [9]}],
#  ['TC1001B', 1, 3, 1, 'Jorge Rodríguez', 0, {}],
#  ['TC2008B', 1, 3, 7, 'Israel Tabarez', 2, {'Jueves': [17], 'Viernes': [7]}]]

# %%
#['TC3008', 'G1', 'P2', 'M1', 'Victor Manon', '#Horas a la semana', 'Horario']

# %%
print(cromosome[0])
print(cromosome[1])
print(cromosome[2])
# Out:
# ['TC1001B', 1, 3, 6, 'Jorge Rodríguez', 1, {'Jueves': [18]}]
# ['TC1033', 1, 3, 1, 'Mauricio Paletta', 4, {'Lunes': [18], 'Viernes': [13, 15], 'Miercoles': [11]}]
# ['TI1015', 1, 3, 1, 'Roberto Leyva', 4, {'Viernes': [7], 'Lunes': [9], 'Martes': [12, 17]}]

# %%
gen_element = randint(1,len(cromosome[0]))
print(cromosome[0][gen_element])
# Out:
# 1

# %%
#['TC3008', 'G1', 'P2', 'M1', 'Victor Manon', '#Horas a la semana', 'Horario']

# %%
print(professors_for_course['TC3002B'])
print(list(professors_for_course['TC3002B'].keys()))
print(list(professors_for_course['TC3002B']['1']))
# Out:
# {'1': ['Juan Alvarado', 'Roberto Leyva', 'Mauricio Paletta'], '2': ['Roberto Leyva', 'Mauricio Paletta'], '3': ['Mauricio Paletta', 'José Aguilera'], '4': ['Pedro Hernandez']}
# ['1', '2', '3', '4']
# ['Juan Alvarado', 'Roberto Leyva', 'Mauricio Paletta']

# %%
def mutation_operator(cromesome, semester):

    groups = groups_even
    if semester: groups = groups_odd
    periods = period_even
    if semester: periods = period_odd

    
    gen_i = randint(0,len(cromosome)-1)
    pick_gen_element = choice([1,2])
    gen = cromosome[gen_i]
    print(gen)
    if pick_gen_element == 1:#Profesor de modulo
        options = list(professors_for_course[gen[0]][str(gen[3])])
        #options = list(professors_for_course['TC1001B'][str(gen[3])])
        #print(options)
        #print(gen)
        #m = randint(0,len(options)-1)
        m = choice(options)
        #print('m',m)
        gen[4] = m
        #print(gen)
        return gen
    
    elif pick_gen_element == 2: #Horario
        days = ['Lunes', 'Martes', 'Miercoles', 'Jueves', 'Viernes']

        hour = gen[5]
        #print(hour)
        horario = {}
        while hour != 0:
            day = choice(days)
            new_hour = randint(7,20)
            if day in horario:
                if new_hour not in horario[day]:
                    horario[day].append(new_hour)
                    hour -= 1
            else:
                horario[day] = [new_hour]
                hour -= 1
        
        for day in horario.keys():
            horario[day].sort()

        gen[6] = horario
        #print(gen)
        return gen

# %%
mutation_operator(cromosome, True)
# Out:
# ['TC1032', 1, 2, 1, 'Yerly Flores', 4, {'Martes': [13], 'Jueves': [16], 'Lunes': [11, 20]}]
# ['TC1032',
#  1,
#  2,
#  1,
#  'Fernando Ruiz',
#  4,
#  {'Martes': [13], 'Jueves': [16], 'Lunes': [11, 20]}]

# %%
#['TC3008', 'G1', 'P2', 'M1', 'Victor Manon', '#Horas a la semana', 'Horario']
